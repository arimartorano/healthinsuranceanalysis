# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

healthinsdf=pd.read_csv('/Users/adelamar_ifds/healthinsuranceanalysis/states.csv')
healthinsdf.head(5)
# Out:
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                  14.6%                 10.1%
# 1     Alaska                  19.9%                 14.9%
# 2    Arizona                  16.9%                 10.8%
# 3   Arkansas                  17.5%                  9.5%
# 4  California                 18.5%                  8.6%
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.5%
# 1                              -5%
# 2                            -6.1%
# 3                              -8%
# 4                            -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# 0                                        215000
# 1                                         36000
# 2                                        410000
# 3                                        234000
# 4                                       3826000
#
#    Employer Health Insurance Coverage (2015)  \
# 0                                    2545000
# ...

# %%
healthinsdf.describe()
# Out:
#        Health Insurance Coverage Change (2010-2015)  \
# count                                  5.200000e+01
# mean                                   7.479423e+05
# std                                    2.691466e+06
# min                                    1.500000e+04
# 25%                                    9.725000e+04
# 50%                                    2.245000e+05
# 75%                                    4.122500e+05
# max                                    1.930400e+07
#
#        Employer Health Insurance Coverage (2015)  \
# count                               5.200000e+01
# mean                                6.626615e+06
# std                                 2.370240e+07
# min                                 3.350000e+05
# 25%                                 8.797500e+05
# 50%                                 2.305500e+06
# 75%                                 4.386500e+06
# max                                 1.722920e+08
#
# ...

# %%
healthinsdf.info
# Out:
# <bound method DataFrame.info of                    State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0               Alabama                  14.6%                 10.1%
# 1                Alaska                  19.9%                 14.9%
# 2               Arizona                  16.9%                 10.8%
# 3              Arkansas                  17.5%                  9.5%
# 4             California                 18.5%                  8.6%
# 5               Colorado                 15.9%                  8.1%
# 6            Connecticut                  9.1%                    6%
# 7              Delaware                   9.7%                  5.9%
# 8   District of Columbia                  7.6%                  3.8%
# 9               Florida                  21.3%                 13.3%
# 10              Georgia                  19.7%                 13.9%
# 11                Hawaii                  7.9%                    4%
# ...

# %%
healthinsdf.columns
# Out:
# Index(['State', 'Uninsured Rate (2010)', 'Uninsured Rate (2015)',
#        'Uninsured Rate Change (2010-2015)',
#        'Health Insurance Coverage Change (2010-2015)',
#        'Employer Health Insurance Coverage (2015)',
#        'Marketplace Health Insurance Coverage (2016)',
#        'Marketplace Tax Credits (2016)', 'Average Monthly Tax Credit (2016)',
#        'State Medicaid Expansion (2016)', 'Medicaid Enrollment (2013)',
#        'Medicaid Enrollment (2016)', 'Medicaid Enrollment Change (2013-2016)',
#        'Medicare Enrollment (2016)'],
#       dtype='object')

# %%
healthinsdf.isnull().sum()
# Out:
# State                                           0
# Uninsured Rate (2010)                           0
# Uninsured Rate (2015)                           0
# Uninsured Rate Change (2010-2015)               0
# Health Insurance Coverage Change (2010-2015)    0
# Employer Health Insurance Coverage (2015)       0
# Marketplace Health Insurance Coverage (2016)    0
# Marketplace Tax Credits (2016)                  0
# Average Monthly Tax Credit (2016)               0
# State Medicaid Expansion (2016)                 1
# Medicaid Enrollment (2013)                      2
# Medicaid Enrollment (2016)                      0
# Medicaid Enrollment Change (2013-2016)          2
# Medicare Enrollment (2016)                      0
# dtype: int64

# %%
healthinsdf.isna().sum()
# Out:
# State                                           0
# Uninsured Rate (2010)                           0
# Uninsured Rate (2015)                           0
# Uninsured Rate Change (2010-2015)               0
# Health Insurance Coverage Change (2010-2015)    0
# Employer Health Insurance Coverage (2015)       0
# Marketplace Health Insurance Coverage (2016)    0
# Marketplace Tax Credits (2016)                  0
# Average Monthly Tax Credit (2016)               0
# State Medicaid Expansion (2016)                 1
# Medicaid Enrollment (2013)                      2
# Medicaid Enrollment (2016)                      0
# Medicaid Enrollment Change (2013-2016)          2
# Medicare Enrollment (2016)                      0
# dtype: int64

# %%
healthinsdf.shape
# Out:
# (52, 14)

# %%
healthinsdf.dtypes.unique()
# Out:
# array([dtype('O'), dtype('int64'), dtype('float64')], dtype=object)

# %%
healthinsdf.describe().transpose()
# Out:
#                                               count          mean  \
# Health Insurance Coverage Change (2010-2015)   52.0  7.479423e+05
# Employer Health Insurance Coverage (2015)      52.0  6.626615e+06
# Marketplace Health Insurance Coverage (2016)   52.0  4.262050e+05
# Marketplace Tax Credits (2016)                 52.0  3.611388e+05
# Medicaid Enrollment (2013)                     50.0  2.255699e+06
# Medicaid Enrollment (2016)                     52.0  2.828190e+06
# Medicaid Enrollment Change (2013-2016)         50.0  6.442463e+05
# Medicare Enrollment (2016)                     52.0  2.173923e+06
#
#                                                        std       min  \
# Health Insurance Coverage Change (2010-2015)  2.691466e+06   15000.0
# Employer Health Insurance Coverage (2015)     2.370240e+07  335000.0
# Marketplace Health Insurance Coverage (2016)  1.538234e+06   13313.0
# Marketplace Tax Credits (2016)                1.306590e+06    1224.0
# ...

# %%
healthinsdf.isnull().any()
# Out:
# State                                           False
# Uninsured Rate (2010)                           False
# Uninsured Rate (2015)                           False
# Uninsured Rate Change (2010-2015)               False
# Health Insurance Coverage Change (2010-2015)    False
# Employer Health Insurance Coverage (2015)       False
# Marketplace Health Insurance Coverage (2016)    False
# Marketplace Tax Credits (2016)                  False
# Average Monthly Tax Credit (2016)               False
# State Medicaid Expansion (2016)                  True
# Medicaid Enrollment (2013)                       True
# Medicaid Enrollment (2016)                      False
# Medicaid Enrollment Change (2013-2016)           True
# Medicare Enrollment (2016)                      False
# dtype: bool

# %%
correlation = healthinsdf.corr().round(2)
plt.figure(figsize = (14,7))
sns.heatmap(correlation, annot = True, cmap = 'RdPu_r')
# Out:
# /var/folders/t8/9qqw45pj2ns236fmzm2y_lfr0000gp/T/ipykernel_92696/599930184.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = healthinsdf.corr().round(2)
# <AxesSubplot: >
